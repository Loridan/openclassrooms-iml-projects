# %% [markdown]
# # 3 - Analyse des données
#
# ---
#
# **Import des dépendances et des données**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

filenamePath = 'en.openfoodfacts.org.products-df5.csv'
dataframe5 = pd.read_csv(filenamePath)

# %%
#from google.colab import files
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-1d74d8f5-716a-4e90-abb0-b27148235227" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d74d8f5-716a-4e90-abb0-b27148235227">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving en.openfoodfacts.org.products-df5.csv to en.openfoodfacts.org.products-df5.csv

# %%
#import io
#dataframe5 = pd.read_csv(io.BytesIO(uploaded[filenamePath]))

# %%
dataframe5.describe()
# Out:
#              lipides       glucides      proteines           sels
# count  583904.000000  583904.000000  583904.000000  583904.000000
# mean       13.970499      28.686183       8.413338       1.110978
# std        16.523547      27.137594       8.703167       3.110685
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.100000       4.600000       2.040000       0.100000
# 50%         8.000000      17.190000       6.060000       0.617500
# 75%        22.500000      53.330000      12.000000       1.332500
# max        99.990000      99.950000      99.000000      99.900000

# %%
sns.boxplot(data=dataframe5, orient="h")

# %%
sns.displot(dataframe5, x="lipides")
sns.displot(dataframe5, x="glucides")
sns.displot(dataframe5, x="proteines")
sns.displot(dataframe5, x="sels")
sns.catplot(x="nutriscore", kind="count", data=dataframe5)

# %% [markdown]
# Nous pouvons voir que nous avons beaucoup d'outliers, que la distribution est fortement asymétrique, que le le jeu n'est pas équilibré.
#
# suite :
#
# *   analyse bivariée
#
# *   matrice des corrélations
#
# *   feature encoding
#
# *   feature normalization
#
# *   feature engineering
#
# *   feature selection
#
# *   imbalances

# %%
sns.pairplot(data=dataframe5, hue="nutriscore")

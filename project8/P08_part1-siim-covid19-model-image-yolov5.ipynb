# %% [markdown]
# ### **import dependencies**

# %%
import os
import shutil
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split
import yaml

from kaggle_secrets import UserSecretsClient
import wandb
from wandb.keras import WandbCallback

import cv2
import pydicom

from pathlib import Path
from tqdm.auto import tqdm

# %% [markdown]
# ### **configuration and initialization**

# %%
SIIM_COVID19_DETECTION_DIR = '/kaggle/input/siim-covid19-detection/'
PART0_RESIZED_DIR = '/kaggle/input/part0-siim-covid19-first-look-resized-512px/'
YOLOV5_DIR = '/kaggle/input/yolov5/yolov5/'
YOLOV5_W_DIR = '/kaggle/working/yolov5/yolov5/'

TEMP_DIR = '/kaggle/temp/'
INPUT_DIR = PART0_RESIZED_DIR+'data/'
OUTPUT_DIR = DATASET_DIR = TEMP_DIR+'data/'

TRAIN_IMAGES_DIR = DATASET_DIR + 'images/train/'
VAL_IMAGES_DIR = DATASET_DIR +'images/valid/'
TRAIN_LABELS_DIR = DATASET_DIR + 'labels/train/'
VAL_LABELS_DIR = DATASET_DIR +'labels/valid/'

BATCH_SIZE = 8
EPOCHS = 50
IMG_SIZE = WIDTH = HEIGHT = 512

TRAIN_IMAGE_LEVEL_PATH = SIIM_COVID19_DETECTION_DIR+'train_image_level.csv'
TRAIN_STUDY_LEVEL_PATH = SIIM_COVID19_DETECTION_DIR+'train_study_level.csv'
META_PATH = PART0_RESIZED_DIR+'meta.csv'

INTERPOLATION = cv2.INTER_LANCZOS4

WANDB_PROJECT_NAME = 'project8-kaggle-covid19'
WANDB_ENTITY_NAME = ''

# %%
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("WANDB_API_KEY1")
os.environ['WANDB_API_KEY'] = secret_value_0

#wandb.login()
wandb.init(project=WANDB_PROJECT_NAME)
config = wandb.config 
config.batch_size = BATCH_SIZE

# %cd ../../

os.makedirs(TRAIN_IMAGES_DIR, exist_ok=True)
os.makedirs(VAL_IMAGES_DIR, exist_ok=True)
os.makedirs(TRAIN_LABELS_DIR, exist_ok=True)
os.makedirs(VAL_LABELS_DIR, exist_ok=True)
# Out:
# wandb: Currently logged in as: adrien-loridan (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.32 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.26<br/>
#                 Syncing run <strong style="color:#cdcd00">earthy-music-95</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/adrien-loridan/project8-kaggle-covid19" target="_blank">https://wandb.ai/adrien-loridan/project8-kaggle-covid19</a><br/>
#                 Run page: <a href="https://wandb.ai/adrien-loridan/project8-kaggle-covid19/runs/8gaqnxgo" target="_blank">https://wandb.ai/adrien-loridan/project8-kaggle-covid19/runs/8gaqnxgo</a><br/>
#                 Run data is saved locally in <code>/kaggle/working/wandb/run-20210617_085947-8gaqnxgo</code><br/><br/>
# /

# %%
shutil.copytree(YOLOV5_DIR, YOLOV5_W_DIR)
# Out:
# '/kaggle/working/yolov5/yolov5/'

# %% [markdown]
# ### **load csv file**

# %%
df_train_image_level = pd.read_csv(META_PATH)
df_train_image_level['path'] = df_train_image_level.apply(lambda row: INPUT_DIR+(row.path.split('/')[-1]), axis=1)

# %% [markdown]
# ### **Object Detection with yolov5**

# %% [markdown]
# **train test split**

# %%
train_df, valid_df = train_test_split(df_train_image_level, test_size=0.2, random_state=42)

train_df = train_df.copy()
valid_df = valid_df.copy()

train_df.loc[:, 'split'] = 'train'
valid_df.loc[:, 'split'] = 'valid'

df_train_image_level = pd.concat([train_df, valid_df]).reset_index(drop=True)
df_train_image_level.sample(4)
# Out:
#                 id                                              boxes  \
# 1296  5e14522be0ff                                                NaN
# 215   4cbc17936e7d                                                NaN
# 888   3d446575cd76  [{'x': 519.35443, 'y': 623.05001, 'width': 551...
# 4991  d26d72f208bc                                                NaN
#
#                                                   label StudyInstanceUID  \
# 1296                                     none 1 0 0 1 1     fdb830b6745f
# 215                                      none 1 0 0 1 1     79c3bf957d49
# 888   opacity 1 519.35443 623.05001 1070.68647 1900....     ba07cc459be2
# 4991                                     none 1 0 0 1 1     7f7379e733a2
#
#                                                    path image_level  \
# 1296  /kaggle/input/part0-siim-covid19-first-look-re...        none
# 215   /kaggle/input/part0-siim-covid19-first-look-re...        none
# 888   /kaggle/input/part0-siim-covid19-first-look-re...     opacity
# 4991  /kaggle/input/part0-siim-covid19-first-look-re...        none
#
#       Negative for Pneumonia  Typical Appearance  Indeterminate Appearance  \
# 1296                       1                   0                         0
# 215                        0                   1                         0
# 888                        0                   1                         0
# 4991                       1                   0                         0
#
#       Atypical Appearance  study_level   width  height  split
# 1296                    0            0  3480.0  4248.0  train
# 215                     0            1  2544.0  3056.0  train
# 888                     0            1  2416.0  2872.0  train
# 4991                    0            0  2021.0  2021.0  train

# %% [markdown]
# **create dir split train valid and copy image for training**

# %%
[os.makedirs(dir, exist_ok=True) for dir in [TRAIN_IMAGES_DIR,
                                             VAL_IMAGES_DIR,
                                             TRAIN_LABELS_DIR,
                                             VAL_LABELS_DIR]]
for i in tqdm(range(len(df_train_image_level))):
    row = df_train_image_level.loc[i]
    if os.path.exists(row.path):
        if row.split == 'train':
            shutil.copy(row.path, f'{TRAIN_IMAGES_DIR}{row.id}.jpg')
        else:
            shutil.copy(row.path, f'{VAL_IMAGES_DIR}{row.id}.jpg')
# Out:
#   0%|          | 0/6334 [00:00<?, ?it/s]

# %% [markdown]
# **create data yaml yolov5**

# %%
data_yaml = dict(
    train = f'../../../../../.{TRAIN_IMAGES_DIR}',
    val = f'../../../../../.{VAL_IMAGES_DIR}',
    nc = 2,
    names = ['none','opacity']
)

with open(YOLOV5_W_DIR+'data/data.yaml', 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=False)

# %% [markdown]
# **convert results .txt to df_train_image_level**

# %%
def get_bbox(row):
    bboxes = []
    bbox = []
    for i, l in enumerate(row.label.split(' ')):
        if (i % 6 == 0) | (i % 6 == 1):
            continue
        bbox.append(float(l))
        if i % 6 == 5:
            bboxes.append(bbox)
            bbox = []  
            
    return bboxes

def scale_bbox(row, bboxes):
    # Get scaling factor
    scale_x = IMG_SIZE/row.width
    scale_y = IMG_SIZE/row.height
    
    scaled_bboxes = []
    for bbox in bboxes:
        x = int(np.round(bbox[0]*scale_x, 4))
        y = int(np.round(bbox[1]*scale_y, 4))
        x1 = int(np.round(bbox[2]*(scale_x), 4))
        y1= int(np.round(bbox[3]*scale_y, 4))

        scaled_bboxes.append([x, y, x1, y1]) 
        
    return scaled_bboxes

def get_yolo_format_bbox(img_w, img_h, bboxes):
    yolo_boxes = []
    for bbox in bboxes:
        w = bbox[2] - bbox[0] 
        h = bbox[3] - bbox[1] 
        xc = bbox[0] + int(np.round(w/2)) 
        yc = bbox[1] + int(np.round(h/2)) 
        
        yolo_boxes.append([f'{xc/img_w:.6f}',f'{yc/img_h:.6f}' ,f'{w/img_w:.6f}' ,f'{h/img_h:.6f}'])
    
    return yolo_boxes

# %% [markdown]
# **create label txt files**

# %%
if not os.listdir(f'{TRAIN_LABELS_DIR}'):
    for i in tqdm(range(len(df_train_image_level))):
        row = df_train_image_level.loc[i]
        img_id = row.id
        split = row.split
        label = row.image_level

        if row.split=='train':
            file_name = f'{TRAIN_LABELS_DIR}{row.id}.txt'
        else:
            file_name = f'{VAL_LABELS_DIR}{row.id}.txt'


        if label=='opacity':
            bboxes = get_bbox(row)
            scale_bboxes = scale_bbox(row, bboxes)
            yolo_bboxes = get_yolo_format_bbox(IMG_SIZE, IMG_SIZE, scale_bboxes)

            with open(file_name, 'w') as f:
                for bbox in yolo_bboxes:
                    bbox = [1]+bbox
                    bbox = [str(i) for i in bbox]
                    bbox = ' '.join(bbox)
                    f.write(bbox)
                    f.write('\n')
# Out:
#   0%|          | 0/6334 [00:00<?, ?it/s]

# %% [markdown]
# **training**

# %%
# %cd {YOLOV5_W_DIR}
# Out:
# /kaggle/working/yolov5/yolov5

# %%
# !python train.py --img {IMG_SIZE} \
                 --batch-size {BATCH_SIZE} \
                 --epochs {EPOCHS} \
                 --data data.yaml \
                 --weights yolov5s.pt \
                 --save_period 1\
                 --project {WANDB_PROJECT_NAME}
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# 2021-06-17 09:01:05.201780: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Currently logged in as: adrien-loridan (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.32 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# 2021-06-17 09:01:08.440618: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-17 09:01:08.443721: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Tracking run with wandb version 0.10.26
# wandb: Syncing run exp
# wandb: ⭐️ View project at https://wandb.ai/adrien-loridan/project8-kaggle-covid19
# wandb: 🚀 View run at https://wandb.ai/adrien-loridan/project8-kaggle-covid19/runs/qxyfdfgn
# wandb: Run data is saved locally in /kaggle/working/yolov5/yolov5/wandb/run-20210617_090106-qxyfdfgn
# wandb: Run `wandb offline` to turn off syncing.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wandb: Waiting for W&B process to finish, PID 155
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /kaggle/working/yolov5/yolov5/wandb/run-20210617_090106-qxyfdfgn/logs/debug.log
# wandb: Find internal logs for this run at: /kaggle/working/yolov5/yolov5/wandb/run-20210617_090106-qxyfdfgn/logs/debug-internal.log
# wandb: Run summary:
# wandb:                 train/box_loss 0.04814
# wandb:                 train/obj_loss 0.01946
# wandb:                 train/cls_loss 3e-05
# wandb:              metrics/precision 0.51093
# wandb:                 metrics/recall 0.4266
# wandb:                metrics/mAP_0.5 0.39904
# wandb:           metrics/mAP_0.5:0.95 0.1154
# wandb:                   val/box_loss 0.05464
# wandb:                   val/obj_loss 0.011
# wandb:                   val/cls_loss 4e-05
# wandb:                          x/lr0 0.00203
# wandb:                          x/lr1 0.00203
# wandb:                          x/lr2 0.00203
# wandb:                       _runtime 6554
# wandb:                     _timestamp 1623927020
# wandb:                          _step 50
# wandb: Run history:
# wandb:         train/box_loss █▅▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/obj_loss ██▆▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁
# wandb:         train/cls_loss █▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      metrics/precision ▁▂▃▅▆▅▅▅▆▅▆▆▆▆▇▇▇▇▇▇██▇███▇▇██▇███▇█▇▇▇▇
# wandb:         metrics/recall ▁▁▁▄▃▅▄▅▆▅▆▅▆▇▅▇▆▇▇▇▆▆▇▇█▇▇▇▇▇▇▇▇▇█▇▇█▇▇
# wandb:        metrics/mAP_0.5 ▁▂▂▄▅▅▅▅▆▆▆▆▆▇▆▇▇▇▇█▇█████████▇█████████
# wandb:   metrics/mAP_0.5:0.95 ▁▁▂▃▄▅▄▅▆▆▆▅▆▆▆▇▆▇▇▇▇▇▇███▇▇██▇██████▇██
# wandb:           val/box_loss █▇▆▆▄▃▄▄▂▄▂▃▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▁▁▂▁▁▁▁▁▁▁▂▁
# wandb:           val/obj_loss █▆▅▄▄▃▄▃▂▂▂▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           val/cls_loss █▃▃▂▂▂▁▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▂▁▂▁▁▁▁
# wandb:                  x/lr0 ▂▅██████▇▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁
# wandb:                  x/lr1 ▂▅██████▇▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁
# wandb:                  x/lr2 █▅▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               _runtime ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:             _timestamp ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:                  _step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:
# wandb: Synced 5 W&B file(s), 337 media file(s), 50 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced exp: https://wandb.ai/adrien-loridan/project8-kaggle-covid19/runs/qxyfdfgn

# %% [markdown]
# ### **ref**

# %% [markdown]
# * https://www.kaggle.com/xhlulu
# * https://www.kaggle.com/yujiariyasu
# * https://www.kaggle.com/ayuraj
# * https://www.kaggle.com/dschettler8845
# ....
